# %%
import json, nltk, os, re, string
from nltk import RegexpTokenizer

# Settings
title = "La Divina Commedia"
author = "Dante Alighieri"
year = "1308-1320"
lang = "it"
cantica = "Inferno" # Optional. It can be empty ""
pathToFile = "texts/" + lang + "/" + cantica + "/"

tercet_number = 1
last_word_odd = ""
last_word_even = ""
rhyme_length = 0
canto_num = 0

last_line = ""
print(last_line)

# Helper to remove punctuation
tokenizer = RegexpTokenizer(r'\w+')

clean = str.maketrans("", "", string.punctuation)

'''
Loop over files in texts directory
Docs: https://docs.python.org/3/tutorial/inputoutput.html\
#reading-and-writing-files
'''
for root, dirs, files in os.walk(pathToFile):
    cantos = []
    lines = []
    
    count_stars = 0
    count_christ = 0
    
    for file in sorted(files):

        # Reset line and tercet number at the beginning of each canto
        line_number = 0
        tercet_number = 1

        if file.endswith(".txt"):

            with open(pathToFile + file) as canto:
                
                last_line = canto.readlines()[-1]

            with open(pathToFile + file) as canto:
                repetitions = {}

                for line in canto:
                    '''
                    If the line is not blank, assign a line number,
                    otherwise print an empty line to separate tercets
                    '''
                    if line.strip():
                        line_number += 1
                        # Add to lines list for retrieval
                        line_whole = line
                        lines.append(line_whole)
                        # Remove punctuation
                        line = line.translate(clean)
                        
                        line = line.lower()
                        
                        words = line.split()
                        
                        for word in words:
                            if (len(word) > 2):
                                if word not in repetitions:
                                    repetitions[word] = 0
                                repetitions[word] += 1

                                if word == "stelle":
                                    print("Canto num:", canto_num, "Line number", line_number, ":", word,
                                         "text:", line_whole)
                                    count_stars += 1

                                if word == "cristo":
                                    print("Canto num:", canto_num, "Line number", line_number, ":", word,
                                         "text:", line_whole)
                                    count_christ += 1
        canto_num += 1
    print("Stelle:", count_stars)
    print("Cristo:", count_christ)

# reverse sorting
sorted_reps = sorted(repetitions, key=lambda x: repetitions[x], reverse=True)
for k in sorted_reps:
    print("{} : {}".format(k, repetitions[k]))
# Out:
# Canto num: 1 Line number 38 : stelle text: e ’l sol montava ’n sù con quelle stelle
#
# Canto num: 3 Line number 23 : stelle text: risonavan per l’aere sanza stelle,
#
# Canto num: 16 Line number 83 : stelle text: e torni a riveder le belle stelle,
#
# Canto num: 20 Line number 50 : stelle text: per sua dimora; onde a guardar le stelle
#
# Canto num: 26 Line number 127 : stelle text: Tutte le stelle già de l’altro polo
#
# Canto num: 34 Line number 139 : stelle text: E quindi uscimmo a riveder le stelle.
# Stelle: 6
# Cristo: 0
# che : 22
# per : 12
# non : 11
# era : 8
# com’ : 8
# quando : 7
# con : 7
# maestro : 6
# quel : 6
# come : 5
# tanto : 5
# disse : 4
# quella : 4
# loco : 4
# lui : 4
# tre : 4
# sotto : 4
# noi : 3
# dinanzi : 3
# mio : 3
# l’emisperio : 3
# duca : 3
# ché : 3
# col : 3
# capo : 3
# divenni : 3
# poco : 3
# qual : 3
# del : 3
# fuor : 3
# tutto : 3
# parte : 3
# elli : 3
# quanto : 3
# due : 3
# dal : 3
# giù : 3
# punto : 3
# ov’ : 3
# d’un : 3
# verso : 2
# però : 2
# grossa : 2
# haï : 1
# piedi : 1
# picciola : 1
# spera : 1
# l’altra : 1
# faccia : 1
# giudecca : 1
# man : 1
# scala : 1
# prim’ : 1
# cadde : 1
# cielo : 1
# terra : 1
# pria : 1
# sporse : 1
# velo : 1
# venne : 1
# forse : 1
# fuggir : 1
# lasciò : 1
# vòto : 1
# ch’appar : 1
# ricorse» : 1
# luogo : 1
# belzebù : 1
# remoto : 1
# tomba : 1
# distende : 1
# vista : 1
# suono : 1
# noto : 1
# ruscelletto : 1
# quivi : 1
# discende : 1
# buca : 1
# roso : 1
# corso : 1
# avvolge : 1
# ascoso : 1
# intrammo : 1
# ritornar : 1
# nel : 1
# chiaro : 1
# cura : 1
# aver : 1
# d’alcun : 1
# riposo : 1
# salimmo : 1
# primo : 1
# secondo : 1
# cose : 1
# belle : 1
# porta : 1
# ciel : 1
# pertugio : 1
# tondo : 1
# uscimmo : 1
# riveder : 1
# stelle : 1

# %%
import json, nltk, os, re, string
from nltk import RegexpTokenizer

# Settings
title = "La Divina Commedia"
author = "Dante Alighieri"
year = "1308-1320"
lang = "it"
cantica = "Purgatorio" # Optional. It can be empty ""
pathToFile = "texts/" + lang + "/" + cantica + "/"

tercet_number = 1
last_word_odd = ""
last_word_even = ""
rhyme_length = 0
canto_num = 0

last_line = ""
print(last_line)

# Helper to remove punctuation
tokenizer = RegexpTokenizer(r'\w+')

clean = str.maketrans("", "", string.punctuation)

'''
Loop over files in texts directory
Docs: https://docs.python.org/3/tutorial/inputoutput.html\
#reading-and-writing-files
'''
for root, dirs, files in os.walk(pathToFile):
    cantos = []
    lines = []
    
    count_stars = 0
    count_christ = 0
    
    for file in sorted(files):

        # Reset line and tercet number at the beginning of each canto
        line_number = 0
        tercet_number = 1

        if file.endswith(".txt"):

            with open(pathToFile + file) as canto:
                
                last_line = canto.readlines()[-1]

            with open(pathToFile + file) as canto:
                repetitions = {}

                for line in canto:
                    '''
                    If the line is not blank, assign a line number,
                    otherwise print an empty line to separate tercets
                    '''
                    if line.strip():
                        line_number += 1
                        # Add to lines list for retrieval
                        line_whole = line
                        lines.append(line_whole)
                        # Remove punctuation
                        line = line.translate(clean)
                        
                        line = line.lower()
                        
                        words = line.split()
                        
                        for word in words:
                            if (len(word) > 2):
                                if word not in repetitions:
                                    repetitions[word] = 0
                                repetitions[word] += 1

                                if word == "stelle":
                                    print("Canto num:", canto_num, "Line number", line_number, ":", word,
                                         "text:", line_whole)
                                    count_stars += 1

                                if word == "cristo":
                                    print("Canto num:", canto_num, "Line number", line_number, ":", word,
                                         "text:", line_whole)
                                    count_christ += 1
        canto_num += 1
    print("Stelle:", count_stars)
    print("Cristo:", count_christ)

# reverse sorting
sorted_reps = sorted(repetitions, key=lambda x: repetitions[x], reverse=True)
for k in sorted_reps:
    print("{} : {}".format(k, repetitions[k]))
# Out:
# Canto num: 1 Line number 23 : stelle text: a l’altro polo, e vidi quattro stelle
#
# Canto num: 6 Line number 100 : stelle text: giusto giudicio da le stelle caggia
#
# Canto num: 8 Line number 86 : stelle text: pur là dove le stelle son più tarde,
#
# Canto num: 8 Line number 91 : stelle text: Ond’ elli a me: «Le quattro chiare stelle
#
# Canto num: 17 Line number 72 : stelle text: che le stelle apparivan da più lati.
#
# Canto num: 18 Line number 77 : stelle text: facea le stelle a noi parer più rade,
#
# Canto num: 20 Line number 87 : cristo text: e nel vicario suo Cristo esser catto.
#
# Canto num: 21 Line number 8 : cristo text: che Cristo apparve a’ due ch’erano in via,
#
# Canto num: 23 Line number 74 : cristo text: che menò Cristo lieto a dire ‘Elì’,
#
# Canto num: 26 Line number 129 : cristo text: nel quale è Cristo abate del collegio,
#
# Canto num: 27 Line number 89 : stelle text: ma, per quel poco, vedea io le stelle
#
# Canto num: 30 Line number 111 : stelle text: secondo che le stelle son compagne,
#
# Canto num: 31 Line number 106 : stelle text: «Noi siam qui ninfe e nel ciel siamo stelle;
#
# Canto num: 32 Line number 102 : cristo text: di quella Roma onde Cristo è romano.
#
# Canto num: 33 Line number 41 : stelle text: a darne tempo già stelle propinque,
#
# Canto num: 33 Line number 145 : stelle text: puro e disposto a salire a le stelle.
# Stelle: 11
# Cristo: 5
# che : 39
# non : 18
# come : 12
# più : 11
# per : 9
# con : 7
# lei : 4
# mia : 4
# dio : 4
# son : 4
# sua : 4
# poi : 3
# rispuose : 3
# donna : 3
# così : 3
# suo : 3
# quando : 3
# occhi : 3
# disse : 3
# com’ : 3
# perché : 3
# dinanzi : 3
# sanza : 3
# voi : 3
# chi : 3
# colpa : 3
# qual : 3
# mente : 3
# quella : 3
# tua : 3
# quanto : 3
# voglia : 3
# dolce : 2
# donne : 2
# bëatrice : 2
# quelle : 2
# foco : 2
# videbitis : 2
# mie : 2
# tutte : 2
# sette : 2
# solo : 2
# terra : 2
# «vien : 2
# s’io : 2
# fui : 2
# omai : 2
# maggior : 2
# essa : 2
# voglio : 2
# tempo : 2
# veggio : 2
# già : 2
# stelle : 2
# perch’ : 2
# ’ntelletto : 2
# tosto : 2
# parole : 2
# del : 2
# ch’è : 2
# vista : 2
# volte : 2
# fatto : 2
# tanto : 2
# acqua : 2
# mio : 2
# detto : 2
# sovra : 2
# vostra : 2
# parola : 2
# veggi : 2
# mai : 2
# letè : 2
# gente : 2
# questa : 2
# qui : 2
# bella : 2
# ‘deus : 1
# venerunt : 1
# gentes’ : 1
# alternando : 1
# tre : 1
# quattro : 1
# salmodia : 1
# incominciaro : 1
# lagrimando : 1
# sospirosa : 1
# pia : 1
# ascoltava : 1
# fatta : 1
# poco : 1
# croce : 1
# cambiò : 1
# maria : 1
# l’altre : 1
# vergini : 1
# dier : 1
# loco : 1
# dir : 1
# levata : 1
# dritta : 1
# colorata : 1
# ‘modicum : 1
# iterum : 1
# sorelle : 1
# dilette : 1
# modicum : 1
# vos : 1
# me’ : 1
# mise : 1
# innanzi : 1
# dopo : 1
# accennando : 1
# mosse : 1
# savio : 1
# ristette : 1
# sen : 1
# giva : 1
# credo : 1
# fosse : 1
# decimo : 1
# passo : 1
# posto : 1
# percosse : 1
lang = "it"
cantica = "Paradiso" # Optional. It can be empty ""
pathToFile = "texts/" + lang + "/" + cantica + "/"

tercet_number = 1
last_word_odd = ""
last_word_even = ""
rhyme_length = 0
canto_num = 0

last_line = ""
print(last_line)

# Helper to remove punctuation
tokenizer = RegexpTokenizer(r'\w+')

clean = str.maketrans("", "", string.punctuation)

'''
Loop over files in texts directory
Docs: https://docs.python.org/3/tutorial/inputoutput.html\
#reading-and-writing-files
'''
for root, dirs, files in os.walk(pathToFile):
    cantos = []
    lines = []
    
    count_stars = 0
    count_christ = 0
    
    for file in sorted(files):

        # Reset line and tercet number at the beginning of each canto
        line_number = 0
        tercet_number = 1

        if file.endswith(".txt"):

            with open(pathToFile + file) as canto:
                
                last_line = canto.readlines()[-1]

            with open(pathToFile + file) as canto:
                repetitions = {}

                for line in canto:
                    '''
                    If the line is not blank, assign a line number,
                    otherwise print an empty line to separate tercets
                    '''
                    if line.strip():
                        line_number += 1
                        # Add to lines list for retrieval
                        line_whole = line
                        lines.append(line_whole)
                        # Remove punctuation
                        line = line.translate(clean)
                        
                        line = line.lower()
                        
                        words = line.split()
                        
                        for word in words:
                            if (len(word) > 2):
                                if word not in repetitions:
                                    repetitions[word] = 0
                                repetitions[word] += 1

                                if word == "stelle":
                                    print("Canto num:", canto_num, "Line number", line_number, ":", word,
                                         "text:", line_whole)
                                    count_stars += 1

                                if word == "cristo":
                                    print("Canto num:", canto_num, "Line number", line_number, ":", word,
                                         "text:", line_whole)
                                    count_christ += 1
        canto_num += 1
    print("Stelle:", count_stars)
    print("Cristo:", count_christ)

# reverse sorting
sorted_reps = sorted(repetitions, key=lambda x: repetitions[x], reverse=True)
for k in sorted_reps:
    print("{} : {}".format(k, repetitions[k]))
# Out:
# Canto num: 2 Line number 137 : stelle text: multiplicata per le stelle spiega,
#
# Canto num: 4 Line number 23 : stelle text: parer tornarsi l’anime a le stelle,
#
# Canto num: 6 Line number 14 : cristo text: una natura in Cristo esser, non piùe,
#
# Canto num: 7 Line number 138 : stelle text: in queste stelle che ’ntorno a lor vanno.
#
# Canto num: 8 Line number 110 : stelle text: che muovon queste stelle non son manchi,
#
# Canto num: 9 Line number 120 : cristo text: del trïunfo di Cristo fu assunta.
#
# Canto num: 10 Line number 78 : stelle text: come stelle vicine a’ fermi poli,
#
# Canto num: 11 Line number 72 : cristo text: ella con Cristo pianse in su la croce.
#
# Canto num: 11 Line number 102 : cristo text: predicò Cristo e li altri che ’l seguiro,
#
# Canto num: 11 Line number 107 : cristo text: da Cristo prese l’ultimo sigillo,
#
# Canto num: 12 Line number 37 : cristo text: L’essercito di Cristo, che sì caro
#
# Canto num: 12 Line number 71 : cristo text: sì come de l’agricola che Cristo
#
# Canto num: 12 Line number 73 : cristo text: Ben parve messo e famigliar di Cristo:
#
# Canto num: 12 Line number 75 : cristo text: fu al primo consiglio che diè Cristo.
#
# Canto num: 13 Line number 4 : stelle text: quindici stelle che ’n diverse plage
#
# Canto num: 14 Line number 104 : cristo text: ché quella croce lampeggiava Cristo,
#
# Canto num: 14 Line number 106 : cristo text: ma chi prende sua croce e segue Cristo,
#
# Canto num: 14 Line number 108 : cristo text: vedendo in quell’ albor balenar Cristo.
#
# Canto num: 17 Line number 51 : cristo text: là dove Cristo tutto dì si merca.
#
# Canto num: 19 Line number 72 : cristo text: di Cristo né chi legga né chi scriva;
#
# Canto num: 19 Line number 104 : cristo text: non salì mai chi non credette ’n Cristo,
#
# Canto num: 19 Line number 108 : cristo text: a lui, che tal che non conosce Cristo;
#
# Canto num: 20 Line number 47 : cristo text: non seguir Cristo, per l’esperïenza
#
# Canto num: 22 Line number 112 : stelle text: O glorïose stelle, o lume pregno
#
# Canto num: 23 Line number 20 : cristo text: del trïunfo di Cristo e tutto ’l frutto
#
# Canto num: 23 Line number 72 : cristo text: che sotto i raggi di Cristo s’infiora?
#
# Canto num: 25 Line number 15 : cristo text: che lasciò Cristo d’i vicari suoi;
#
# Canto num: 25 Line number 70 : stelle text: Da molte stelle mi vien questa luce;
#
# Canto num: 26 Line number 53 : cristo text: de l’aguglia di Cristo, anzi m’accorsi
#
# Canto num: 27 Line number 40 : cristo text: «Non fu la sposa di Cristo allevata
#
# Canto num: 29 Line number 98 : cristo text: ne la passion di Cristo e s’interpuose,
#
# Canto num: 29 Line number 109 : cristo text: Non disse Cristo al suo primo convento:
#
# Canto num: 31 Line number 3 : cristo text: che nel suo sangue Cristo fece sposa;
#
# Canto num: 31 Line number 107 : cristo text: ‘Segnor mio Iesù Cristo, Dio verace,
#
# Canto num: 32 Line number 20 : cristo text: la fede in Cristo, queste sono il muro
#
# Canto num: 32 Line number 24 : cristo text: quei che credettero in Cristo venturo;
#
# Canto num: 32 Line number 27 : cristo text: quei ch’a Cristo venuto ebber li visi.
#
# Canto num: 32 Line number 83 : cristo text: sanza battesmo perfetto di Cristo
#
# Canto num: 32 Line number 85 : cristo text: Riguarda omai ne la faccia che a Cristo
#
# Canto num: 32 Line number 125 : cristo text: di Santa Chiesa a cui Cristo le chiavi
#
# Canto num: 33 Line number 145 : stelle text: l’amor che move il sole e l’altre stelle.
# Stelle: 9
# Cristo: 32
# che : 42
# per : 19
# non : 12
# tanto : 11
# più : 10
# mia : 8
# ch’i’ : 7
# qual : 6
# mio : 6
# come : 6
# del : 5
# nel : 5
# questo : 5
# ciò : 5
# lume : 5
# tal : 5
# luce : 5
# se’ : 4
# suo : 4
# sua : 4
# così : 4
# tua : 4
# occhi : 4
# veder : 4
# miei : 4
# prieghi : 4
# vista : 4
# mente : 4
# quel : 4
# ch’io : 4
# quella : 4
# creatura : 3
# qui : 3
# grazia : 3
# una : 3
# possa : 3
# con : 3
# perché : 3
# ancor : 3
# era : 3
# ché : 3
# vidi : 3
# lei : 3
# tutto : 3
# sola : 3
# tuo : 2
# mortali : 2
# vuol : 2
# pur : 2
# questi : 2
# l’universo : 2
# mai : 2
# priego : 2
# dopo : 2
# quanto : 2
# son : 2
# già : 2
# stesso : 2
# raggio : 2
# l’alta : 2
# quinci : 2
