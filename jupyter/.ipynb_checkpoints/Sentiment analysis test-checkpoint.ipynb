# %% [markdown]
# ## Vader vs Naïve Bayes Classifier

# %% [markdown]
# Reference: https://opensourceforu.com/2016/12/analysing-sentiments-nltk/

# %% [markdown]
# ## Testing Vader on the Inferno

# %%
import json, nltk, os
from nltk.sentiment.vader import SentimentIntensityAnalyzer 

lang = "en"
cantica = "Inferno"
pathToFile = "texts/" + lang + "/" + cantica + "/"

negatives = []
neutrals = []
positives = []
compounds = []
total_lines = 0
lines = []

for root, dirs, files in os.walk(pathToFile):
    for file in sorted(files):
        if file.endswith(".txt"):
            with open(pathToFile + file) as canto:
                line_number = 0
                sid = SentimentIntensityAnalyzer()
                for line in canto:
                    if line.strip():
                        line_number += 1
                        total_lines += 1
                        ss = sid.polarity_scores(line)
                        for k in ss:
                            if (k == "neg"):
                                negatives.append(ss[k])
                            elif (k == "neu"):
                                neutrals.append(ss[k])
                            elif (k == "pos"):
                                positives.append(ss[k])
                            elif (k == "compound"):
                                compounds.append(ss[k])
                                compound = ss[k]
                                if (compound < 0):
                                    color = "red"
                                elif (compound > 0):
                                    color = "#2d8bcF"
                                else:
                                    color = "#ffbb00"

                        # Prepare the JSON file for viz
                        json_line_obj = {
                            "line_number": line_number,
                            "text": line,
                            "compound": compound,
                            "color": color
                        }

                    if json_line_obj not in lines:
                        lines.append(json_line_obj)

# Build the full thing
json_obj = {
    "cantica": cantica,
    "lang": lang,
    "lines": lines
}

print(total_lines)
mean_neg = sum(negatives) / total_lines
mean_neu = sum(neutrals) / total_lines
mean_pos = sum(positives) / total_lines
mean_comp = sum(compounds) / total_lines
print(cantica)
print("Compound:", mean_comp)
print("Mean negative:", mean_neg, "\nMean neutral:", 
      mean_neu, "\nMean positive:", mean_pos)
# Out:
# 4720
# Inferno
# Compound: -0.02548993644067798
# Mean negative: 0.07977690677966097
# Mean neutral: 0.8590080508474581
# Mean positive: 0.06121419491525423

# %%
import nltk, os
from nltk.sentiment.vader import SentimentIntensityAnalyzer 

lang = "en"
cantica = "Purgatorio"
pathToFile = "texts/" + lang + "/" + cantica + "/"

negatives = []
neutrals = []
positives = []
compounds = []
total_lines = 0

for root, dirs, files in os.walk(pathToFile):
    for file in sorted(files):
        if file.endswith(".txt"):
            with open(pathToFile + file) as canto:
                sid = SentimentIntensityAnalyzer()
                for line in canto:
                    if line.strip():
                        total_lines += 1
                        ss = sid.polarity_scores(line)
                        for k in ss:
                            if (k == "neg"):
                                negatives.append(ss[k])
                            elif (k == "neu"):
                                neutrals.append(ss[k])
                            elif (k == "pos"):
                                positives.append(ss[k])
                            elif (k == "compound"):
                                compounds.append(ss[k])
                                compound = ss[k]
                                if (compound < 0):
                                    color = "#d65108"
                                elif (compound > 0):
                                    color = "#2d8bcF"
                                else:
                                    color = "#ffbb00"

print(total_lines)
mean_neg = sum(negatives) / total_lines
mean_neu = sum(neutrals) / total_lines
mean_pos = sum(positives) / total_lines
mean_comp = sum(compounds) / total_lines
print(cantica)
print("Compound:", mean_comp)
print("Mean negative:", mean_neg, "\nMean neutral:", 
      mean_neu, "\nMean positive:", mean_pos)
# Out:
# 4755
# Purgatorio
# Compound: 0.04260921135646684
# Mean negative: 0.06073522607781285
# Mean neutral: 0.8496187171398526
# Mean positive: 0.08964521556256577

# %%
import nltk, os
from nltk.sentiment.vader import SentimentIntensityAnalyzer 

lang = "en"
cantica = "Paradiso"
pathToFile = "texts/" + lang + "/" + cantica + "/"

negatives = []
neutrals = []
positives = []
compounds = []
total_lines = 0

for root, dirs, files in os.walk(pathToFile):
    for file in sorted(files):
        if file.endswith(".txt"):
            with open(pathToFile + file) as canto:
                sid = SentimentIntensityAnalyzer()
                for line in canto:
                    if line.strip():
                        total_lines += 1
                        ss = sid.polarity_scores(line)
                        for k in ss:
                            if (k == "neg"):
                                negatives.append(ss[k])
                            elif (k == "neu"):
                                neutrals.append(ss[k])
                            elif (k == "pos"):
                                positives.append(ss[k])
                            elif (k == "compound"):
                                compounds.append(ss[k])
                                compound = ss[k]
                                if (compound < 0):
                                    color = "#d65108"
                                elif (compound > 0):
                                    color = "#2d8bcF"
                                else:
                                    color = "#ffbb00"

print(total_lines)
mean_neg = sum(negatives) / total_lines
mean_neu = sum(neutrals) / total_lines
mean_pos = sum(positives) / total_lines
mean_comp = sum(compounds) / total_lines
print(cantica)
print("Compound:", mean_comp)
print("Mean negative:", mean_neg, "\nMean neutral:", 
      mean_neu, "\nMean positive:", mean_pos)
# Out:
# 4758
# Paradiso
# Compound: 0.1118575241698195
# Mean negative: 0.0434201345102985
# Mean neutral: 0.8333379571248382
# Mean positive: 0.12324253888188315

# %% [markdown]
# ## Testing Naïve Bayes Classifier

# %% [markdown]
# Training the data using the manually collated file training_dataset_en.csv

# %%
import csv, nltk, os
import pandas as pd
from nltk.tokenize import word_tokenize

# Step 1 – Training the data
training_data = []

with open('training_dataset_en.csv') as file:
    for row in csv.reader(file):
        # Ignore empty text cells
        if (row[0] != ""):
            training_data.append((row[0], row[1]))

# %%
# Step 2 
dictionary = set(word.lower() for passage in training_data for word in word_tokenize(passage[0]))

# %%
# Step 3
training = [({word: (word in word_tokenize(x[0])) for word in dictionary}, x[1]) for x in training_data]

# %%
# Step 4 – the classifier is trained with sample data
classifier = nltk.NaiveBayesClassifier.train(training)

# %% [markdown]
# Testing the text against the trained data

# %%
lang = "en"
cantica = "Inferno"
pathToFile = "texts/" + lang + "/" + cantica + "/"
total_lines = 0
positive = 0
negative = 0
neutral = 0

for root, dirs, files in os.walk(pathToFile):
    for file in sorted(files):
        if file.endswith(".txt"):
            with open(pathToFile + file) as canto:
                for line in canto:
                    if line.strip():
                        total_lines += 1
                        test_data_features = { word.lower(): (word in word_tokenize(line.lower())) for word in dictionary }
                        if (classifier.classify(test_data_features) == "negative"):
                            negative += 1
                            print("neg:", line)
                        elif (classifier.classify(test_data_features) == "positive"):
                            positive += 1
                            print("pos:", line)
                        else:
                            neutral += 1

print(cantica)
print("Negative:", negative)
print("Positive:", positive)
print("Neutral:", neutral)

print("Negative pol:", negative/total_lines)
print("Positive pol:", positive/total_lines)
print("Neutral pol:", neutral/total_lines)
# Out:
# pos: when Divine Love first moved those things of beauty;
#
# pos: that she can never sate her greedy will;
#
# pos: O Muses, o high genius, help me now;
#
# neg: see if the force in me is strong enough
#
# neg: For, if the Enemy of every evil
#
# neg: When she had finished with her words to me,
#
# neg: “Here one must leave behind all hesitation;
#
# neg: here every cowardice must meet its death.
#
# pos: “Master, what is it that I hear? Who are
#
# neg: which waits for all who have no fear of God.
#
# pos: similarly, the evil seed of Adam
#
# neg: “My son,” the gracious master said to me,
#
# neg: and like a man whom sleep has seized, I fell.
# neg: And he to me: “The anguish of the people
#
# pos: of that belief which vanquishes all errors,
#
# neg: the crown he wore, a sign of victory.
#
# neg: He carried off the shade of our first father,
#
# neg: of his son Abel, and the shade of Noah,
#
# pos: “O you who honor art and science both,
#
# pos: who are these souls whose dignity has kept
#
# neg: Soon after they had talked a while together,
#
# pos: We drew aside to one part of the meadow,
#
# neg: And I have reached a part where no thing gleams.
# neg: Minos, as soon as he had seen me, said:
#
# neg: seized me, and I was like a man astray.
#
# pos: Love, that can quickly seize the gentle heart,
#
# pos: took hold of him because of the fair body
#
# pos: taken from me—how that was done still wounds me.
#
# pos: Love, that releases no beloved from loving,
#
# pos: took hold of me so strongly through his beauty
#
# neg: Love led the two of us unto one death.
#
# neg: These words were borne across from them to us.
#
# neg: move me to tears of sorrow and of pity.
#
# pos: was kissed by one who was so true a lover,
#
# neg: I fainted, as if I had met my death.
#
# neg: And then I fell as a dead body falls.
# pos: The gentle sage, aware of everything,
#
# neg: while, wheeling weights, they used their chests to push.
#
# neg: when they have reached the two points of the circle
#
# neg: Ill giving and ill keeping have robbed both
#
# pos: that every part may shine unto the other,
#
# neg: and for this reason, men change state so often.
#
# pos: even by those who should give praise to her—
#
# neg: they blame her wrongfully with words of scorn.
#
# pos: But she is blessed and does not hear these things;
#
# pos: forming a swamp that bears the name of Styx.
#
# neg: the souls of those whom anger has defeated;
#
# neg: And I to him: “In weeping and in grieving,
#
# neg: began to turn his teeth against himself.
#
# neg: in anger: “Who is this who, without death,
#
# neg: And my wise master made a sign that said
#
# pos: “O my dear guide, who more than seven times
#
# neg: “Turn round and keep your eyes shut fast, for should
#
# neg: enough to make both of the shorelines quake:
#
# neg: for that, had both his throat and chin stripped clean.”
#
# pos: the state of things that such a fortress guarded,
#
# neg: as soon as I had entered, looked about.
#
# neg: “If they were driven out,” I answered him,
#
# neg: “If they were slow,” he said, “to learn that art,
#
# neg: that is more torment to me than this bed.
#
# pos: It seems, if I hear right, that you can see
#
# neg: we should know nothing of your human state.
#
# neg: He said: “More than a thousand lie with me:
#
# neg: enticed to leave the true path by Photinus.”
#
# pos: the bond of love that nature forges; thus,
#
# pos: I said; “it has made plain for me the nature
#
# neg: points out, and not in just one place,” he said,
#
# pos: that when it can, your art would follow nature,
#
# pos: From these two, art and nature, it is fitting,
#
# neg: like one whom fury devastates within.
#
# neg: felt love (by which, as some believe, the world
#
# neg: who brought such years of grief to Sicily.
#
# neg: He pointed out one shade, alone, apart,
#
# neg: had we been nothing more than souls of serpents.”
#
# neg: cause pain and for that pain provide a vent.
#
# pos: To make these strange things clear, I must explain
#
# neg: by Rhea for her son; to hide him better,
#
# neg: when he cried out, she had her servants clamor.
#
# pos: be sure to cleanse yourself of their foul ways.
#
# neg: “If my desire were answered totally,”
#
# neg: therefore, let Fortune turn her wheel as she
#
# neg: No sooner had I reached the place where one
#
# neg: he now must wheel about both peeled and naked,
#
# neg: more brief than time it takes to say “amen”;
#
# neg: I said within myself, “to this strange sign—
#
# neg: go now, and see the state in which they are.
#
# neg: the sight of shade enough to make him shudder,
#
# pos: come as I thought): “See that you hold me tight.”
#
# neg: the Lovely Lady, then to violate her?”
#
# neg: expression to the sound of those true words.
#
# neg: he looks behind and walks a backward path.
#
# pos: may bless if they should chance to come that way.
#
# neg: she halted with her slaves to ply her arts;
#
# neg: These were his words to me; meanwhile we journeyed.
# neg: Then my good master said to me: “Don’t let
#
# neg: Yet if you two still want to go ahead,
#
# pos: nearby, another ridge will form a path.
#
# neg: If you know how to go, I want no escort.
#
# neg: Their brows are menacing, they promise trouble.”
#
# neg: The mouse had fallen in with evil cats;
#
# neg: and said: “Stand off there, while I fork him fast.”
#
# neg: and threatened all of them with raging looks.
#
# neg: if I bring greater torment to my friends.”
#
# pos: O you who read, hear now of this new sport:
#
# neg: sent four to fly out toward the other shore
#
# neg: than any hound whose teeth have trapped a hare.”
#
# neg: while saying: “Master, if you don’t conceal
#
# neg: will lift her son and run without a stop—
#
# neg: just like a son, and not like a companion.
#
# neg: such tears distilled by grief? And let me know
#
# pos: gave us a false account of this affair.”
#
# neg: they said he was a liar and father of lies.”
#
# neg: and much more steep than we had crossed before.
#
# neg: I knew him as a man of blood and anger.”

# %%
lang = "en"
cantica = "Paradiso"
pathToFile = "texts/" + lang + "/" + cantica + "/"
total_lines = 0
positive = 0
negative = 0
neutral = 0

for root, dirs, files in os.walk(pathToFile):
    for file in sorted(files):
        if file.endswith(".txt"):
            with open(pathToFile + file) as canto:
                for line in canto:
                    if line.strip():
                        total_lines += 1
                        test_data_features = { word.lower(): (word in word_tokenize(line.lower())) for word in dictionary }
                        if (classifier.classify(test_data_features) == "negative"):
                            negative += 1
                        elif (classifier.classify(test_data_features) == "positive"):
                            positive += 1
                        else:
                            neutral += 1
print(cantica)
print("Negative:", negative)
print("Positive:", positive)
print("Neutral:", neutral)

print("Negative pol:", negative/total_lines)
print("Positive pol:", positive/total_lines)
print("Neutral pol:", neutral/total_lines)

# %%
lang = "en"
cantica = "Purgatorio"
pathToFile = "texts/" + lang + "/" + cantica + "/"
total_lines = 0
positive = 0
negative = 0
neutral = 0

for root, dirs, files in os.walk(pathToFile):
    for file in sorted(files):
        if file.endswith(".txt"):
            with open(pathToFile + file) as canto:
                for line in canto:
                    if line.strip():
                        total_lines += 1
                        test_data_features = { word.lower(): (word in word_tokenize(line.lower())) for word in dictionary }
                        if (classifier.classify(test_data_features) == "negative"):
                            negative += 1
                        elif (classifier.classify(test_data_features) == "positive"):
                            positive += 1
                        else:
                            neutral += 1
print(cantica)
print("Negative:", negative)
print("Positive:", positive)
print("Neutral:", neutral)

print("Negative pol:", negative/total_lines)
print("Positive pol:", positive/total_lines)
print("Neutral pol:", neutral/total_lines)
